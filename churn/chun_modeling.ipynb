# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv(r"C:\Users\solomon\Downloads\practice\chun\Churn_Modelling.csv")

# %% [markdown]
# Details of the Dataset

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# Check for any missing value

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# Check for duplicated columns

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %% [markdown]
# Column info

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# Dataset info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# Unqinue Values

# %%
df.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %% [markdown]
# Drop columns that are not relevant

# %%
df_train = df.drop(["RowNumber","CustomerId"], axis = 1)

# %%
df_train.head()
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %% [markdown]
# Columns data type

# %%
df_train.dtypes
# Out:
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# Seperating categorical variable from numerical variable

# %%
catergoric_var = ["Geography","Gender","HasCrCard","IsActiveMember", "Exited"]

# %%
num_var = ["CreditScore","Age","Tenure","Balance","NumOfProducts","EstimatedSalary"]

# %%
df_train["Gender"].value_counts().index
# Out:
# Index(['Male', 'Female'], dtype='object', name='Gender')

# %% [raw]
# Univerate analysis of catergorical variable

# %%
for i in catergoric_var:
    total_observation = df[i].value_counts()
    value_label = total_observation.index
    plt.figure(figsize= (5,5),layout = 'constrained')
    plt.pie(total_observation,autopct="%1.1f%%",labels= value_label,startangle= 75)
    plt.legend()
    plt.tight_layout
    plt.show()

# %% [markdown]
# Univarate Analysis for numerical Variable

# %%
num_var = ["CreditScore","Age","Tenure","Balance","NumOfProducts","EstimatedSalary"]

# %%
for i in num_var:
    sns.displot(data = df_train, x = i, kde = True,)
    
    plt.figure(figsize=(10,10), layout = "constrained",clear=True)
    plt.show()

# %%
df_train.head()
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %% [markdown]
# Bivariate Analysis for Numerical Variable and Output

# %%
for i in num_var:
    sns.displot(data = df_train, x = i, hue = "Exited", fill = True, kind = "kde")
    plt.figure(figsize=(5,5), layout = "tight")
    plt.show()

# %%
df_train.head()
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %% [markdown]
# Bivariate Analysis for Categorical Variavle

# %%
for i in catergoric_var:

    sns.countplot(data = df_train, x= i, hue="Exited")
    plt.figure(figsize=(5,5), layout = "tight")
    plt.show()

# %%
df[num_var]
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  EstimatedSalary
# 0             619   42       2       0.00              1        101348.88
# 1             608   41       1   83807.86              1        112542.58
# 2             502   42       8  159660.80              3        113931.57
# 3             699   39       1       0.00              2         93826.63
# 4             850   43       2  125510.82              1         79084.10
# ...           ...  ...     ...        ...            ...              ...
# 9995          771   39       5       0.00              2         96270.64
# 9996          516   35      10   57369.61              1        101699.77
# 9997          709   36       7       0.00              1         42085.58
# 9998          772   42       3   75075.31              2         92888.52
# 9999          792   28       4  130142.79              1         38190.78
#
# [10000 rows x 6 columns]

# %%
df_train.head()
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %%
df_train = df_train.drop("Surname",axis = 1)

# %%
df_train.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df_train.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# Handling the categorical Variable

# %%
df_train =  pd.get_dummies(df_train, columns=["Geography","Gender"], drop_first=True, dtype=int)

# %%
df_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# ...

# %% [markdown]
# Correlation Between Categorical Variable and numeric variable

# %%
df_train.corr()
# Out:
#                    CreditScore       Age    Tenure   Balance  NumOfProducts  \
# CreditScore           1.000000 -0.003965  0.000842  0.006268       0.012238
# Age                  -0.003965  1.000000 -0.009997  0.028308      -0.030680
# Tenure                0.000842 -0.009997  1.000000 -0.012254       0.013444
# Balance               0.006268  0.028308 -0.012254  1.000000      -0.304180
# NumOfProducts         0.012238 -0.030680  0.013444 -0.304180       1.000000
# HasCrCard            -0.005458 -0.011721  0.022583 -0.014858       0.003183
# IsActiveMember        0.025651  0.085472 -0.028362 -0.010084       0.009612
# EstimatedSalary      -0.001384 -0.007201  0.007784  0.012797       0.014204
# Exited               -0.027094  0.285323 -0.014001  0.118533      -0.047820
# Geography_Germany     0.005538  0.046897 -0.000567  0.401110      -0.010419
# Geography_Spain       0.004780 -0.001685  0.003868 -0.134892       0.009039
# ...

# %% [raw]
# Renaming and Rearraning the columns

# %%
df_train.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Geography_Germany',
#        'Geography_Spain', 'Gender_Male'],
#       dtype='object')

# %%
df_train.columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
       'IsActiveMember', 'EstimatedSalary', 'Exited', 'Geography_Germany',
       'Geography_Spain', 'Gender']

df_train = df_train[['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
       'IsActiveMember', 'EstimatedSalary', 'Geography_Germany',
       'Geography_Spain', 'Gender', 'Exited']]

# %% [markdown]
# Correclation Analysis

# %%
plt.figure(figsize=(15,15))

sns.heatmap(data = df_train.corr(), linewidths= 0.5, annot=True)

plt.show()

# %%
num_var
# Out:
# ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

# %% [raw]
# Detecting Outliers

# %%
fig,axis = plt.subplots(nrows= 1, ncols = 6, figsize=(20,6))

axis[0].boxplot(df_train["CreditScore"]) 
axis[0].set_title("CreditScore") 

axis[1].boxplot(df_train["Age"])
axis[1].set_title("Age")

axis[2].boxplot(df_train["Tenure"])
axis[2].set_title("Tenure")


axis[3].boxplot(df_train["Balance"])
axis[3].set_title("Balance")

axis[4].boxplot(df_train["NumOfProducts"])
axis[4].set_title("NumOfProduts")

axis[5].boxplot(df_train["EstimatedSalary"]) 
axis[5].set_title("EstimatedSalary")
# Out:
# Text(0.5, 1.0, 'EstimatedSalary')

# %%
df_train.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 0               1        101348.88                  0                0
# 1               1        112542.58                  0                1
# 2               0        113931.57                  0                0
# 3               0         93826.63                  0                0
# 4               1         79084.10                  0                1
#
#    Gender  Exited
# 0       0       1
# 1       0       0
# 2       0       1
# 3       0       0
# 4       0       0

# %%
df_train.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Geography_Germany',
#        'Geography_Spain', 'Gender', 'Exited'],
#       dtype='object')

# %% [markdown]
# Prepraring data for modeling

# %%
df_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 0                  1        101348.88                  0                0
# ...

# %% [markdown]
# Treating Outliers

# %%
from feature_engine.outliers import OutlierTrimmer
ot = OutlierTrimmer(capping_method="gaussian")
df_nom = ot.fit_transform(df_train)

# %%
df_nom
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 0                  1        101348.88                  0                0
# ...

# %%
df_nom.isna().sum()
# Out:
# CreditScore          0
# Age                  0
# Tenure               0
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Geography_Germany    0
# Geography_Spain      0
# Gender               0
# Exited               0
# dtype: int64

# %% [markdown]
# Splitting data into Independent and dependent Variable

# %%
X = df_nom.iloc[:, :-1]
y = df_nom.iloc[:, -1]

print(X.shape,y.shape)
# Out:
# (9807, 11) (9807,)

# %% [markdown]
# Creating Train and Test Set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, train_size= 0.25, random_state=0)

# %% [markdown]
# Feature Selection

# %%
from sklearn.feature_selection import VarianceThreshold

sel = VarianceThreshold(threshold = 0)
sel.fit(X_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
sum(sel.get_support())
# Out:
# 11

# %%
sel.get_feature_names_out()
# Out:
# array(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#        'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Geography_Germany', 'Geography_Spain', 'Gender'], dtype=object)

# %%
from feature_engine.selection import DropConstantFeatures

sel = DropConstantFeatures(tol=1)
sel.fit(X_train)
# Out:
# DropConstantFeatures()

# %%
sel.features_to_drop_
# Out:
# []

# %% [markdown]
# Training the model

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=5)
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=5)

# %% [markdown]
# Make Prediction

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix

check = confusion_matrix(y_test,y_pred)

# %%
check
# Out:
# array([[5430,  444],
#        [ 792,  690]], dtype=int64)

# %%
from sklearn.model_selection import cross_val_score

accuracy = cross_val_score(estimator=classifier,X = X_train, y=y_train, cv=10)
accuracy.mean()
# Out:
# 0.8298656047784968

# %%
accuracy.std()
# Out:
# 0.0185264670073637

# %%
from sklearn.model_selection import GridSearchCV
parameters = [{"n_estimators":[20,40,60,80,100], "criterion":["gini","entropy", "log_loss"]}]
grid_cv = GridSearchCV(estimator=classifier,param_grid=parameters,scoring="accuracy",n_jobs= -1)
grid_cv = grid_cv.fit(X_train,y_train)

best_score = grid_cv.best_score_
best_param = grid_cv.best_params_

# %%
best_score
# Out:
# 0.8547562242819735

# %%
best_param
# Out:
# {'criterion': 'entropy', 'n_estimators': 80}

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators= 80,criterion="entropy")
classifier = classifier.fit(X_train,y_train)

# %%
y_pred_new = classifier.predict(X_test)

# %%
y_pred_new
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
check = confusion_matrix(y_test,y_pred_new)
check
# Out:
# array([[5649,  225],
#        [ 880,  602]], dtype=int64)
